# %% [markdown]
# # Introduction à la librairie Keras

# %% [markdown]
# Dans le TP précédent, vous avez implémenté l'apprentissage et l'inférence d'un réseau de neurones. En pratique, il est plus courant de faire appel à des librairies qui masquent la complexité de ces algorithmes (notamment le calcul des gradients, réalisé par différentiation automatique). Dans la suite, nous utiliserons pour les TPs la librairie ***Keras***. Dans un premier temps, pour ce TP nous allons détailler sur un exemple simple (le même que pour le TP précédent) les différentes étapes à mettre en place pour entraîner un réseau à l'aide de cette librairie.

# %% [markdown]
# Le bloc de code ci-dessous sera utile pour analyser l'évolution des performances au cours de l'apprentissage

# %%
def plot_training_analysis(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  #plt.figure()
  plt.subplots(1, 2, figsize=(10, 4))


  plt.subplot(1,2,1)
  plt.plot(epochs, acc, 'b', linestyle="--",label='Training acc')
  plt.plot(epochs, val_acc, 'g', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(epochs, loss, 'b', linestyle="--",label='Training loss')
  plt.plot(epochs, val_loss,'g', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %% [markdown]
# ## Exemple de classification binaire simple

# %% [markdown]
# Chargement des données (ce sont les mêmes que lors du dernier TP)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# Génération des données
x, y = datasets.make_blobs(n_samples=250, n_features=2, centers=2, center_box=(- 3, 3), random_state=1)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.legend()
plt.show()

# %% [markdown]
# Dans ce problème, les données $x^{(i)}$ sont les points, on a donc $x^{(i)} \in \mathbb{R}^2$. Les étiquettes $y^{(i)}$ correspondent à la couleur des points (bleue ou rouge), matérialisée par un label (0 ou 1).
#
# Pour résoudre le problème, on peut donc construire un perceptron monocouche à 2 entrées et une sortie.
#
# <center>
# <img src="https://drive.google.com/uc?id=1WfUL0fTE7fjeHMrlGjgH3b_3511ttnO8">
# </center>
#
# Il s'agit d'un problème de classification binaire, il faut donc utiliser une fonction d'activation **sigmoide** sur la couche de sortie.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Définition du modèle, un simple perceptron monocouche.
model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(1, activation='sigmoid', input_dim=2)) # input_dim indique la dimension de la couche d'entrée, ici 2

model.summary() # affiche un résumé du modèle
# Out:
# Model: "sequential_60"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_178 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 3 (12.00 Byte)
# Trainable params: 3 (12.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Le résumé du modèle (*summary*) nous indique le nombre de paramètres du modèle, ici 3 : 2 poids synaptiques et un biais.
#
# Il nous faut maintenant choisir la fonction de coût : pour ce problème de classification binaire, le choix standard est l'entropie croisée binaire (*binary cross-entropy*).
#
# On choisit dans un premier temps un optimiseur standard, la descente de gradient stochastique.

# %%
from tensorflow.keras import optimizers

# Définition de l'optimiseur
sgd = optimizers.SGD(learning_rate=0.1) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15, batch_size=20)

plot_training_analysis(history)
# Out:
# Epoch 1/15
# 12/12 [==============================] - 1s 62ms/step - loss: 0.2468 - accuracy: 0.9156 - val_loss: 0.2286 - val_accuracy: 0.9200
# Epoch 2/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2045 - accuracy: 0.9333 - val_loss: 0.1956 - val_accuracy: 0.9600
# Epoch 3/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1862 - accuracy: 0.9511 - val_loss: 0.1791 - val_accuracy: 0.9600
# Epoch 4/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1752 - accuracy: 0.9511 - val_loss: 0.1671 - val_accuracy: 0.9600
# Epoch 5/15
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1665 - accuracy: 0.9511 - val_loss: 0.1596 - val_accuracy: 0.9600
# Epoch 6/15
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1598 - accuracy: 0.9556 - val_loss: 0.1522 - val_accuracy: 0.9600
# Epoch 7/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1537 - accuracy: 0.9600 - val_loss: 0.1455 - val_accuracy: 0.9600
# Epoch 8/15
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1485 - accuracy: 0.9644 - val_loss: 0.1390 - val_accuracy: 0.9600
# Epoch 9/15
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1435 - accuracy: 0.9644 - val_loss: 0.1329 - val_accuracy: 0.9600
# Epoch 10/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1391 - accuracy: 0.9644 - val_loss: 0.1280 - val_accuracy: 0.9600
# Epoch 11/15
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1354 - accuracy: 0.9689 - val_loss: 0.1243 - val_accuracy: 1.0000
# Epoch 12/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1322 - accuracy: 0.9689 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 13/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1292 - accuracy: 0.9644 - val_loss: 0.1174 - val_accuracy: 1.0000
# Epoch 14/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1263 - accuracy: 0.9644 - val_loss: 0.1148 - val_accuracy: 1.0000
# Epoch 15/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1237 - accuracy: 0.9600 - val_loss: 0.1125 - val_accuracy: 1.0000

# %% [markdown]
# L'apprentissage semble bien se passer : la perte d'apprentissage et la perte de validation décroissent au cours du temps, et l'accuracy est proche de 100% à la fin de l'apprentissage.
#
# La cellule suivante introduit une fonction permettant de visualiser la frontière de décision du modèle appris.

# %%
import numpy as np

def print_decision_boundaries(model, x, y):
  dx, dy = 0.1, 0.1
  y_grid, x_grid = np.mgrid[slice(np.min(x[:,1]), np.max(x[:,1]) + dy, dy),
                  slice(np.min(x[:,0]), np.max(x[:,0]) + dx, dx)]


  x_gen = np.concatenate((np.expand_dims(np.reshape(x_grid, (-1)),1),np.expand_dims(np.reshape(y_grid, (-1)),1)), axis=1)
  z_gen = model.predict(x_gen).reshape(x_grid.shape)

  z_min, z_max = 0, 1

  c = plt.pcolor(x_grid, y_grid, z_gen, cmap='RdBu', vmin=z_min, vmax=z_max)
  plt.colorbar(c)
  plt.plot(x[y==0,0], x[y==0,1], 'r.')
  plt.plot(x[y==1,0], x[y==1,1], 'b.')
  plt.show()

# %%
print_decision_boundaries(model, x_train, y_train)
# Out:
# 198/198 [==============================] - 1s 3ms/step

# %% [markdown]
# ## Exemple de classification plus "complexe"

# %% [markdown]
# Les données de la section précédente sont linéairement séparables : un séparateur linéaire suffit à obtenir des bonnes performances, et un perceptron monocouche est donc bien adapté à la résolution de ce problème.
#
# Traitons maintenant un second problème légèrement plus
# complexe, non linéairement séparable.

# %%
x, y = datasets.make_gaussian_quantiles(n_samples=250, n_features=2, n_classes=2, random_state=1)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

plt.legend()
plt.show()

# %% [markdown]
# **Travail à faire** : commencez par tester un perceptron monocouche comme nous l'avons vu précédemment.

# %%
model2 = Sequential()

model2.add(Dense(1, activation='sigmoid', input_dim=2))

sgd2 = optimizers.SGD(learning_rate=0.1)

model2.compile(optimizer = sgd2,
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

history = model2.fit(x_train, y_train,
                    validation_data = (x_test, y_test),
                    epochs = 30,
                    batch_size = 20)

plot_training_analysis(history)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 1s 24ms/step - loss: 0.7108 - accuracy: 0.5511 - val_loss: 0.7337 - val_accuracy: 0.4800
# Epoch 2/30
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6996 - accuracy: 0.5333 - val_loss: 0.7180 - val_accuracy: 0.5600
# Epoch 3/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6925 - accuracy: 0.5511 - val_loss: 0.7092 - val_accuracy: 0.5600
# Epoch 4/30
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6896 - accuracy: 0.5244 - val_loss: 0.7021 - val_accuracy: 0.6000
# Epoch 5/30
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6890 - accuracy: 0.5422 - val_loss: 0.6981 - val_accuracy: 0.5600
# Epoch 6/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6878 - accuracy: 0.5467 - val_loss: 0.6917 - val_accuracy: 0.6400
# Epoch 7/30
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6867 - accuracy: 0.5733 - val_loss: 0.6912 - val_accuracy: 0.6400
# Epoch 8/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6865 - accuracy: 0.5378 - val_loss: 0.6915 - val_accuracy: 0.6400
# Epoch 9/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.5689 - val_loss: 0.6905 - val_accuracy: 0.6400
# Epoch 10/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.5644 - val_loss: 0.6914 - val_accuracy: 0.6400
# Epoch 11/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.5867 - val_loss: 0.6917 - val_accuracy: 0.6400
# Epoch 12/30
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6869 - accuracy: 0.5556 - val_loss: 0.6919 - val_accuracy: 0.6400
# Epoch 13/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6868 - accuracy: 0.5689 - val_loss: 0.6935 - val_accuracy: 0.6400
# Epoch 14/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.5556 - val_loss: 0.6893 - val_accuracy: 0.6000
# Epoch 15/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.5556 - val_loss: 0.6855 - val_accuracy: 0.6000
# Epoch 16/30
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.5467 - val_loss: 0.6857 - val_accuracy: 0.6000
# Epoch 17/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6874 - accuracy: 0.5867 - val_loss: 0.6832 - val_accuracy: 0.6000
# Epoch 18/30
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6889 - accuracy: 0.5422 - val_loss: 0.6826 - val_accuracy: 0.6000
# Epoch 19/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.5556 - val_loss: 0.6846 - val_accuracy: 0.5200
# Epoch 20/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6878 - accuracy: 0.5067 - val_loss: 0.6884 - val_accuracy: 0.6000
# Epoch 21/30
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6873 - accuracy: 0.5333 - val_loss: 0.6875 - val_accuracy: 0.5200
# Epoch 22/30
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6876 - accuracy: 0.5244 - val_loss: 0.6908 - val_accuracy: 0.5600
# Epoch 23/30
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6872 - accuracy: 0.5422 - val_loss: 0.6904 - val_accuracy: 0.5600
# Epoch 24/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.5244 - val_loss: 0.6911 - val_accuracy: 0.6400
# Epoch 25/30
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6871 - accuracy: 0.5600 - val_loss: 0.6933 - val_accuracy: 0.6400
# Epoch 26/30
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6881 - accuracy: 0.5289 - val_loss: 0.6954 - val_accuracy: 0.6000
# Epoch 27/30
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6868 - accuracy: 0.5467 - val_loss: 0.6895 - val_accuracy: 0.6000
# Epoch 28/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6875 - accuracy: 0.5422 - val_loss: 0.6915 - val_accuracy: 0.6400
# Epoch 29/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6869 - accuracy: 0.5556 - val_loss: 0.6888 - val_accuracy: 0.6000
# Epoch 30/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6864 - accuracy: 0.5600 - val_loss: 0.6877 - val_accuracy: 0.6400

# %% [markdown]
# Un perceptron monocouche ne permet que d'obtenir un séparateur linéaire, ce qui n'est pas suffisant pour apprendre à séparer ces données. La **capacité** du modèle est trop faible, et on est dans une situation de **sous-apprentissage** : la perte d'apprentissage ne diminue pas suffisamment, le modèle n'arrive pas à apprendre correctement l'ensemble d'apprentissage.
#
# Pour résoudre ce problème, il faut ajouter (au moins) une couche cachée au modèle. Voici un exemple ci-dessous, où l'on ajoute une couche cachée à 2 neurones.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# On définit ici un perceptron multicouche à deux couches cachées.
model = Sequential()
model.add(Dense(2, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(1, activation='sigmoid'))

model.summary() # affiche un résumé du modèle

# Définition de l'optimiseur
sgd = optimizers.SGD(learning_rate=0.1)

# Fonction de coût et métrique
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=20)

# Affichage de l'évolution des métriques
plot_training_analysis(history)

# Visualisation du résultat
print_decision_boundaries(model, x_train, y_train)
# Out:
# Model: "sequential_62"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_180 (Dense)           (None, 2)                 6
#
#  dense_181 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 1s 24ms/step - loss: 0.7421 - accuracy: 0.4444 - val_loss: 0.7429 - val_accuracy: 0.4000
# Epoch 2/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7251 - accuracy: 0.4800 - val_loss: 0.7312 - val_accuracy: 0.4000
# Epoch 3/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7173 - accuracy: 0.4889 - val_loss: 0.7228 - val_accuracy: 0.4000
# Epoch 4/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7110 - accuracy: 0.4622 - val_loss: 0.7171 - val_accuracy: 0.3200
# Epoch 5/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7076 - accuracy: 0.4178 - val_loss: 0.7127 - val_accuracy: 0.3200
# Epoch 6/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7044 - accuracy: 0.4267 - val_loss: 0.7097 - val_accuracy: 0.3200
# Epoch 7/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7021 - accuracy: 0.4356 - val_loss: 0.7072 - val_accuracy: 0.3600
# Epoch 8/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7011 - accuracy: 0.4267 - val_loss: 0.7046 - val_accuracy: 0.3600
# Epoch 9/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6997 - accuracy: 0.4444 - val_loss: 0.7027 - val_accuracy: 0.3600
# Epoch 10/50
# 12/12 [==============================] - 0s 11ms/step - loss: 0.6984 - accuracy: 0.4222 - val_loss: 0.7012 - val_accuracy: 0.3600
# Epoch 11/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6973 - accuracy: 0.4222 - val_loss: 0.6997 - val_accuracy: 0.4000
# Epoch 12/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6963 - accuracy: 0.4089 - val_loss: 0.6986 - val_accuracy: 0.4000
# Epoch 13/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6958 - accuracy: 0.4489 - val_loss: 0.6977 - val_accuracy: 0.3600
# Epoch 14/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6951 - accuracy: 0.4489 - val_loss: 0.6962 - val_accuracy: 0.4800
# Epoch 15/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6937 - accuracy: 0.4578 - val_loss: 0.6949 - val_accuracy: 0.6000
# Epoch 16/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.6927 - accuracy: 0.6000 - val_loss: 0.6940 - val_accuracy: 0.5600
# Epoch 17/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6913 - accuracy: 0.4800 - val_loss: 0.6927 - val_accuracy: 0.6000
# Epoch 18/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6904 - accuracy: 0.6000 - val_loss: 0.6920 - val_accuracy: 0.5600
# Epoch 19/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6884 - accuracy: 0.5067 - val_loss: 0.6913 - val_accuracy: 0.4000
# Epoch 20/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6867 - accuracy: 0.5422 - val_loss: 0.6899 - val_accuracy: 0.5200
# Epoch 21/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6846 - accuracy: 0.4622 - val_loss: 0.6881 - val_accuracy: 0.5200
# Epoch 22/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6826 - accuracy: 0.5956 - val_loss: 0.6867 - val_accuracy: 0.5600
# Epoch 23/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6798 - accuracy: 0.5333 - val_loss: 0.6848 - val_accuracy: 0.5600
# Epoch 24/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6762 - accuracy: 0.5956 - val_loss: 0.6828 - val_accuracy: 0.5600
# Epoch 25/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6722 - accuracy: 0.5956 - val_loss: 0.6803 - val_accuracy: 0.5200
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6687 - accuracy: 0.6044 - val_loss: 0.6780 - val_accuracy: 0.5600
# Epoch 27/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6653 - accuracy: 0.6267 - val_loss: 0.6750 - val_accuracy: 0.5200
# Epoch 28/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6602 - accuracy: 0.6044 - val_loss: 0.6729 - val_accuracy: 0.5600
# Epoch 29/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6548 - accuracy: 0.6000 - val_loss: 0.6698 - val_accuracy: 0.5600
# Epoch 30/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6502 - accuracy: 0.5956 - val_loss: 0.6665 - val_accuracy: 0.5600
# Epoch 31/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6462 - accuracy: 0.6044 - val_loss: 0.6638 - val_accuracy: 0.5200
# Epoch 32/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6421 - accuracy: 0.6000 - val_loss: 0.6607 - val_accuracy: 0.5200
# Epoch 33/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6370 - accuracy: 0.6133 - val_loss: 0.6580 - val_accuracy: 0.5600
# Epoch 34/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6332 - accuracy: 0.6133 - val_loss: 0.6562 - val_accuracy: 0.5200
# Epoch 35/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6294 - accuracy: 0.6089 - val_loss: 0.6538 - val_accuracy: 0.5600
# Epoch 36/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6257 - accuracy: 0.6222 - val_loss: 0.6512 - val_accuracy: 0.5600
# Epoch 37/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6220 - accuracy: 0.6178 - val_loss: 0.6470 - val_accuracy: 0.5600
# Epoch 38/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6185 - accuracy: 0.6133 - val_loss: 0.6427 - val_accuracy: 0.5600
# Epoch 39/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6146 - accuracy: 0.6222 - val_loss: 0.6390 - val_accuracy: 0.5600
# Epoch 40/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6108 - accuracy: 0.6356 - val_loss: 0.6339 - val_accuracy: 0.5600
# Epoch 41/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6063 - accuracy: 0.6489 - val_loss: 0.6281 - val_accuracy: 0.6400
# Epoch 42/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6010 - accuracy: 0.6578 - val_loss: 0.6216 - val_accuracy: 0.6000
# Epoch 43/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5961 - accuracy: 0.6667 - val_loss: 0.6166 - val_accuracy: 0.6400
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5909 - accuracy: 0.6711 - val_loss: 0.6125 - val_accuracy: 0.6400
# Epoch 45/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5845 - accuracy: 0.7156 - val_loss: 0.6044 - val_accuracy: 0.7200
# Epoch 46/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5776 - accuracy: 0.7378 - val_loss: 0.5971 - val_accuracy: 0.7200
# Epoch 47/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5692 - accuracy: 0.7422 - val_loss: 0.5893 - val_accuracy: 0.7600
# Epoch 48/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5617 - accuracy: 0.7556 - val_loss: 0.5784 - val_accuracy: 0.8000
# Epoch 49/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5534 - accuracy: 0.7467 - val_loss: 0.5688 - val_accuracy: 0.7600
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5453 - accuracy: 0.7422 - val_loss: 0.5602 - val_accuracy: 0.8000
# 96/96 [==============================] - 0s 1ms/step

# %% [markdown]
# **Travail à faire** : testez l'entraînement de ce modèle, et au besoin ajustez le nombre de neurones de la couche cachée pour obtenir de bons résultats.
#
# **Travail à faire** : testez également de remplacer l'optimiseur SGD par l'optimiseur [Adam](https://keras.io/api/optimizers/adam/)

# %%
model = Sequential()
model.add(Dense(4, activation='relu', input_dim=2))
model.add(Dense(1, activation='sigmoid'))

adam = optimizers.Adam(learning_rate=0.1)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=20)
plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 1s 20ms/step - loss: 0.7218 - accuracy: 0.4800 - val_loss: 0.6352 - val_accuracy: 0.6000
# Epoch 2/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6270 - accuracy: 0.6178 - val_loss: 0.5685 - val_accuracy: 0.6800
# Epoch 3/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5880 - accuracy: 0.6800 - val_loss: 0.5372 - val_accuracy: 0.7600
# Epoch 4/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7689 - val_loss: 0.5218 - val_accuracy: 0.7200
# Epoch 5/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4674 - accuracy: 0.7556 - val_loss: 0.5303 - val_accuracy: 0.8000
# Epoch 6/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4561 - accuracy: 0.8178 - val_loss: 0.5308 - val_accuracy: 0.7200
# Epoch 7/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4509 - accuracy: 0.7822 - val_loss: 0.5320 - val_accuracy: 0.7600
# Epoch 8/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3821 - accuracy: 0.8133 - val_loss: 0.4044 - val_accuracy: 0.8800
# Epoch 9/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3023 - accuracy: 0.8756 - val_loss: 0.3895 - val_accuracy: 0.8400
# Epoch 10/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2792 - accuracy: 0.9022 - val_loss: 0.3227 - val_accuracy: 0.8400
# Epoch 11/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2489 - accuracy: 0.8889 - val_loss: 0.3425 - val_accuracy: 0.8000
# Epoch 12/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2622 - accuracy: 0.9111 - val_loss: 0.4265 - val_accuracy: 0.8400
# Epoch 13/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2312 - accuracy: 0.8889 - val_loss: 0.3434 - val_accuracy: 0.8400
# Epoch 14/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2196 - accuracy: 0.9156 - val_loss: 0.3214 - val_accuracy: 0.8800
# Epoch 15/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2287 - accuracy: 0.8933 - val_loss: 0.3130 - val_accuracy: 0.8400
# Epoch 16/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2206 - accuracy: 0.8889 - val_loss: 0.2613 - val_accuracy: 0.8800
# Epoch 17/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2128 - accuracy: 0.8978 - val_loss: 0.3359 - val_accuracy: 0.8000
# Epoch 18/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2125 - accuracy: 0.9111 - val_loss: 0.3412 - val_accuracy: 0.8000
# Epoch 19/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2181 - accuracy: 0.8889 - val_loss: 0.3203 - val_accuracy: 0.8000
# Epoch 20/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2062 - accuracy: 0.8978 - val_loss: 0.2993 - val_accuracy: 0.8400
# Epoch 21/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2035 - accuracy: 0.8889 - val_loss: 0.3025 - val_accuracy: 0.7600
# Epoch 22/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2012 - accuracy: 0.8978 - val_loss: 0.2904 - val_accuracy: 0.8400
# Epoch 23/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.9067 - val_loss: 0.2865 - val_accuracy: 0.8400
# Epoch 24/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1872 - accuracy: 0.9067 - val_loss: 0.3011 - val_accuracy: 0.8000
# Epoch 25/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1963 - accuracy: 0.9111 - val_loss: 0.2761 - val_accuracy: 0.8400
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1833 - accuracy: 0.9111 - val_loss: 0.2646 - val_accuracy: 0.8800
# Epoch 27/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1908 - accuracy: 0.9156 - val_loss: 0.2707 - val_accuracy: 0.8400
# Epoch 28/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1698 - accuracy: 0.9244 - val_loss: 0.2204 - val_accuracy: 0.9600
# Epoch 29/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1711 - accuracy: 0.9156 - val_loss: 0.2602 - val_accuracy: 0.8800
# Epoch 30/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 0.9244 - val_loss: 0.2149 - val_accuracy: 0.9200
# Epoch 31/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1721 - accuracy: 0.9244 - val_loss: 0.2934 - val_accuracy: 0.8400
# Epoch 32/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1849 - accuracy: 0.9244 - val_loss: 0.2190 - val_accuracy: 0.8800
# Epoch 33/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1936 - accuracy: 0.9200 - val_loss: 0.1843 - val_accuracy: 0.9600
# Epoch 34/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1899 - accuracy: 0.9111 - val_loss: 0.3234 - val_accuracy: 0.8000
# Epoch 35/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1856 - accuracy: 0.9111 - val_loss: 0.1970 - val_accuracy: 0.8400
# Epoch 36/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.9422 - val_loss: 0.2578 - val_accuracy: 0.8800
# Epoch 37/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1508 - accuracy: 0.9244 - val_loss: 0.2044 - val_accuracy: 0.8400
# Epoch 38/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1535 - accuracy: 0.9244 - val_loss: 0.2371 - val_accuracy: 0.8800
# Epoch 39/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1576 - accuracy: 0.9067 - val_loss: 0.2297 - val_accuracy: 0.8800
# Epoch 40/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1581 - accuracy: 0.9200 - val_loss: 0.2526 - val_accuracy: 0.8400
# Epoch 41/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1557 - accuracy: 0.9244 - val_loss: 0.1866 - val_accuracy: 0.8800
# Epoch 42/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1542 - accuracy: 0.9244 - val_loss: 0.2433 - val_accuracy: 0.8800
# Epoch 43/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1599 - accuracy: 0.9289 - val_loss: 0.2123 - val_accuracy: 0.8400
# Epoch 44/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1648 - accuracy: 0.9111 - val_loss: 0.2331 - val_accuracy: 0.8800
# Epoch 45/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1589 - accuracy: 0.9200 - val_loss: 0.2542 - val_accuracy: 0.8400
# Epoch 46/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1672 - accuracy: 0.9289 - val_loss: 0.2491 - val_accuracy: 0.8800
# Epoch 47/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1702 - accuracy: 0.9289 - val_loss: 0.2036 - val_accuracy: 0.8800
# Epoch 48/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1637 - accuracy: 0.9244 - val_loss: 0.3712 - val_accuracy: 0.8000
# Epoch 49/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1805 - accuracy: 0.9200 - val_loss: 0.1653 - val_accuracy: 0.9200
# Epoch 50/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1426 - accuracy: 0.9378 - val_loss: 0.2686 - val_accuracy: 0.8400
# 96/96 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Sur-apprentissage et régularisation

# %% [markdown]
# Dans cette section, nous commençons par altérer un peu les données afin qu'elles comportent du "bruit" : la frontière de décision entre données bleues et rouges n'est plus si claire.

# %%
x, y = datasets.make_gaussian_quantiles(n_samples=250, n_features=2, n_classes=2, random_state=1)
x[y==0] = x[y==0]*1.2
x[y==1] = x[y==1]*0.8

# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

plt.legend()

plt.show()

# %% [markdown]
# **Travail à faire** : Reprenez le modèle à une couche cachée construit précédemment et vérifiez que ce modèle arrive toujours à apprendre une solution satisfaisante.

# %%
model = Sequential()
model.add(Dense(4, activation='relu', input_dim=2))
model.add(Dense(1, activation='sigmoid'))

adam = optimizers.Adam(learning_rate=0.1)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=20)
plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 1s 29ms/step - loss: 0.7060 - accuracy: 0.5067 - val_loss: 0.6575 - val_accuracy: 0.6800
# Epoch 2/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6508 - accuracy: 0.6267 - val_loss: 0.6146 - val_accuracy: 0.6400
# Epoch 3/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6399 - accuracy: 0.5778 - val_loss: 0.6135 - val_accuracy: 0.6400
# Epoch 4/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6437 - accuracy: 0.6000 - val_loss: 0.6272 - val_accuracy: 0.6400
# Epoch 5/50
# 12/12 [==============================] - 0s 11ms/step - loss: 0.5638 - accuracy: 0.7289 - val_loss: 0.6192 - val_accuracy: 0.5200
# Epoch 6/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5492 - accuracy: 0.7333 - val_loss: 0.5973 - val_accuracy: 0.6400
# Epoch 7/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5121 - accuracy: 0.7556 - val_loss: 0.6436 - val_accuracy: 0.6800
# Epoch 8/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5957 - accuracy: 0.7378 - val_loss: 0.9184 - val_accuracy: 0.6000
# Epoch 9/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6259 - accuracy: 0.6844 - val_loss: 0.5996 - val_accuracy: 0.7200
# Epoch 10/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5314 - accuracy: 0.7378 - val_loss: 0.6398 - val_accuracy: 0.6400
# Epoch 11/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5217 - accuracy: 0.7511 - val_loss: 0.5695 - val_accuracy: 0.6000
# Epoch 12/50
# 12/12 [==============================] - 0s 11ms/step - loss: 0.5637 - accuracy: 0.7289 - val_loss: 0.5560 - val_accuracy: 0.6000
# Epoch 13/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4924 - accuracy: 0.7600 - val_loss: 0.6615 - val_accuracy: 0.6800
# Epoch 14/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5032 - accuracy: 0.7600 - val_loss: 0.5799 - val_accuracy: 0.6400
# Epoch 15/50
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4814 - accuracy: 0.7600 - val_loss: 0.6213 - val_accuracy: 0.6400
# Epoch 16/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5582 - accuracy: 0.7244 - val_loss: 0.5542 - val_accuracy: 0.8400
# Epoch 17/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4749 - accuracy: 0.7644 - val_loss: 0.8125 - val_accuracy: 0.7200
# Epoch 18/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5141 - accuracy: 0.7511 - val_loss: 0.5527 - val_accuracy: 0.7200
# Epoch 19/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4980 - accuracy: 0.7867 - val_loss: 0.5808 - val_accuracy: 0.6400
# Epoch 20/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4725 - accuracy: 0.7822 - val_loss: 0.5905 - val_accuracy: 0.6400
# Epoch 21/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4937 - accuracy: 0.7422 - val_loss: 0.5713 - val_accuracy: 0.6800
# Epoch 22/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5103 - accuracy: 0.7511 - val_loss: 0.5568 - val_accuracy: 0.6800
# Epoch 23/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5222 - accuracy: 0.7200 - val_loss: 0.5655 - val_accuracy: 0.6800
# Epoch 24/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5218 - accuracy: 0.7244 - val_loss: 0.7372 - val_accuracy: 0.7200
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5014 - accuracy: 0.7511 - val_loss: 0.5681 - val_accuracy: 0.6400
# Epoch 26/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4954 - accuracy: 0.7511 - val_loss: 0.5222 - val_accuracy: 0.7200
# Epoch 27/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5098 - accuracy: 0.7333 - val_loss: 0.5648 - val_accuracy: 0.6800
# Epoch 28/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4663 - accuracy: 0.7778 - val_loss: 0.5463 - val_accuracy: 0.6800
# Epoch 29/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4780 - accuracy: 0.7422 - val_loss: 0.5359 - val_accuracy: 0.6800
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4811 - accuracy: 0.7600 - val_loss: 0.5934 - val_accuracy: 0.6400
# Epoch 31/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4701 - accuracy: 0.7644 - val_loss: 0.5292 - val_accuracy: 0.7200
# Epoch 32/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4835 - accuracy: 0.7733 - val_loss: 0.5499 - val_accuracy: 0.6400
# Epoch 33/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4688 - accuracy: 0.7733 - val_loss: 0.5718 - val_accuracy: 0.6400
# Epoch 34/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4998 - accuracy: 0.7556 - val_loss: 0.5569 - val_accuracy: 0.6400
# Epoch 35/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4667 - accuracy: 0.7556 - val_loss: 0.8045 - val_accuracy: 0.6800
# Epoch 36/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4692 - accuracy: 0.7644 - val_loss: 0.6092 - val_accuracy: 0.7200
# Epoch 37/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4914 - accuracy: 0.7200 - val_loss: 0.7054 - val_accuracy: 0.6800
# Epoch 38/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4674 - accuracy: 0.7644 - val_loss: 0.5455 - val_accuracy: 0.6800
# Epoch 39/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4766 - accuracy: 0.7733 - val_loss: 0.6862 - val_accuracy: 0.6000
# Epoch 40/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4730 - accuracy: 0.7467 - val_loss: 0.5772 - val_accuracy: 0.6400
# Epoch 41/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4824 - accuracy: 0.7333 - val_loss: 0.5330 - val_accuracy: 0.7600
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5814 - accuracy: 0.7333 - val_loss: 0.8573 - val_accuracy: 0.6400
# Epoch 43/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4960 - accuracy: 0.7600 - val_loss: 0.5406 - val_accuracy: 0.6400
# Epoch 44/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4541 - accuracy: 0.7778 - val_loss: 0.7263 - val_accuracy: 0.6800
# Epoch 45/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4923 - accuracy: 0.7333 - val_loss: 0.5658 - val_accuracy: 0.6400
# Epoch 46/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5120 - accuracy: 0.7689 - val_loss: 0.5593 - val_accuracy: 0.7600
# Epoch 47/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5703 - accuracy: 0.7067 - val_loss: 0.7227 - val_accuracy: 0.6000
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4989 - accuracy: 0.7644 - val_loss: 0.6213 - val_accuracy: 0.6800
# Epoch 49/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4637 - accuracy: 0.7644 - val_loss: 0.5532 - val_accuracy: 0.6800
# Epoch 50/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4603 - accuracy: 0.7689 - val_loss: 0.5610 - val_accuracy: 0.6000
# 62/62 [==============================] - 0s 1ms/step

# %% [markdown]
# L'avantage de ce modèle à une couche cachée est qu'il reste assez simple : il n'a pas une capacité suffisante pour chercher à expliquer à tout prix la distribution des données d'apprentissage. L'accuracy plafonne vers 75% sur l'ensemble d'apprentissage, ce qui semble évoquer du sous-apprentissage, mais en réalité le modèle est satisfaisant car l'accuracy de validation est elle autour de 70%.
#
#
# Une piste d'amélioration pourrait consister à augmenter la capacité du modèle afin d'obtenir de meilleures performances sur l'ensemble d'apprentissage.
#
# **Travail à faire** : Augmentez la capacité du modèle (nombre de couches cachées, nombre de neurones par couche) de sorte d'obtenir une accuracy d'apprentissage d'environ 90%. Qu'observez-vous sur l'accuracy de validation ?

# %%
model = Sequential()
model.add(Dense(1024, activation='relu', input_dim=2))
model.add(Dense(1024, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

adam = optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)
plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 60ms/step - loss: 0.9875 - accuracy: 0.5067 - val_loss: 0.6895 - val_accuracy: 0.5200
# Epoch 2/100
# 12/12 [==============================] - 1s 48ms/step - loss: 0.6505 - accuracy: 0.6756 - val_loss: 0.5621 - val_accuracy: 0.7600
# Epoch 3/100
# 12/12 [==============================] - 1s 44ms/step - loss: 0.5464 - accuracy: 0.7067 - val_loss: 0.5372 - val_accuracy: 0.6800
# Epoch 4/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.5280 - accuracy: 0.7333 - val_loss: 0.4858 - val_accuracy: 0.6800
# Epoch 5/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4863 - accuracy: 0.7333 - val_loss: 0.4593 - val_accuracy: 0.7600
# Epoch 6/100
# 12/12 [==============================] - 1s 42ms/step - loss: 0.5264 - accuracy: 0.7022 - val_loss: 0.4660 - val_accuracy: 0.7200
# Epoch 7/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.5058 - accuracy: 0.7422 - val_loss: 0.4598 - val_accuracy: 0.6800
# Epoch 8/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.5136 - accuracy: 0.7156 - val_loss: 0.5302 - val_accuracy: 0.6800
# Epoch 9/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.5265 - accuracy: 0.7422 - val_loss: 0.5331 - val_accuracy: 0.6000
# Epoch 10/100
# 12/12 [==============================] - 1s 59ms/step - loss: 0.5062 - accuracy: 0.7600 - val_loss: 0.6285 - val_accuracy: 0.6800
# Epoch 11/100
# 12/12 [==============================] - 1s 72ms/step - loss: 0.4762 - accuracy: 0.7422 - val_loss: 0.4235 - val_accuracy: 0.7600
# Epoch 12/100
# 12/12 [==============================] - 1s 66ms/step - loss: 0.4702 - accuracy: 0.7467 - val_loss: 0.6310 - val_accuracy: 0.6800
# Epoch 13/100
# 12/12 [==============================] - 1s 71ms/step - loss: 0.5041 - accuracy: 0.7244 - val_loss: 0.4313 - val_accuracy: 0.8400
# Epoch 14/100
# 12/12 [==============================] - 1s 52ms/step - loss: 0.4670 - accuracy: 0.7600 - val_loss: 0.5314 - val_accuracy: 0.6400
# Epoch 15/100
# 12/12 [==============================] - 1s 50ms/step - loss: 0.4763 - accuracy: 0.7600 - val_loss: 0.4392 - val_accuracy: 0.8400
# Epoch 16/100
# 12/12 [==============================] - 0s 40ms/step - loss: 0.4732 - accuracy: 0.7378 - val_loss: 0.4484 - val_accuracy: 0.6800
# Epoch 17/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4601 - accuracy: 0.7511 - val_loss: 0.4319 - val_accuracy: 0.7600
# Epoch 18/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.4415 - accuracy: 0.7467 - val_loss: 0.5680 - val_accuracy: 0.6800
# Epoch 19/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4286 - accuracy: 0.7422 - val_loss: 0.3955 - val_accuracy: 0.7200
# Epoch 20/100
# 12/12 [==============================] - 0s 38ms/step - loss: 0.4443 - accuracy: 0.7556 - val_loss: 0.5510 - val_accuracy: 0.7200
# Epoch 21/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4401 - accuracy: 0.7378 - val_loss: 0.4710 - val_accuracy: 0.8000
# Epoch 22/100
# 12/12 [==============================] - 0s 38ms/step - loss: 0.4711 - accuracy: 0.7467 - val_loss: 0.4450 - val_accuracy: 0.6800
# Epoch 23/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4696 - accuracy: 0.7333 - val_loss: 0.4514 - val_accuracy: 0.7200
# Epoch 24/100
# 12/12 [==============================] - 1s 42ms/step - loss: 0.4559 - accuracy: 0.7333 - val_loss: 0.4234 - val_accuracy: 0.8000
# Epoch 25/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4765 - accuracy: 0.7644 - val_loss: 0.5507 - val_accuracy: 0.6800
# Epoch 26/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4603 - accuracy: 0.7556 - val_loss: 0.4584 - val_accuracy: 0.7200
# Epoch 27/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4466 - accuracy: 0.7511 - val_loss: 0.6140 - val_accuracy: 0.6400
# Epoch 28/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4310 - accuracy: 0.7600 - val_loss: 0.4705 - val_accuracy: 0.7600
# Epoch 29/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4840 - accuracy: 0.7422 - val_loss: 0.5377 - val_accuracy: 0.7200
# Epoch 30/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4704 - accuracy: 0.7600 - val_loss: 0.4407 - val_accuracy: 0.7200
# Epoch 31/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4441 - accuracy: 0.7733 - val_loss: 0.4166 - val_accuracy: 0.7200
# Epoch 32/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.4436 - accuracy: 0.7600 - val_loss: 0.4669 - val_accuracy: 0.6800
# Epoch 33/100
# 12/12 [==============================] - 1s 44ms/step - loss: 0.4555 - accuracy: 0.7422 - val_loss: 0.4684 - val_accuracy: 0.7200
# Epoch 34/100
# 12/12 [==============================] - 0s 36ms/step - loss: 0.4174 - accuracy: 0.7822 - val_loss: 0.4354 - val_accuracy: 0.7600
# Epoch 35/100
# 12/12 [==============================] - 1s 49ms/step - loss: 0.4178 - accuracy: 0.7511 - val_loss: 0.4293 - val_accuracy: 0.6800
# Epoch 36/100
# 12/12 [==============================] - 1s 68ms/step - loss: 0.4163 - accuracy: 0.7867 - val_loss: 0.4239 - val_accuracy: 0.7600
# Epoch 37/100
# 12/12 [==============================] - 1s 70ms/step - loss: 0.4450 - accuracy: 0.7378 - val_loss: 0.4961 - val_accuracy: 0.7200
# Epoch 38/100
# 12/12 [==============================] - 1s 73ms/step - loss: 0.4474 - accuracy: 0.7289 - val_loss: 0.4241 - val_accuracy: 0.7200
# Epoch 39/100
# 12/12 [==============================] - 1s 44ms/step - loss: 0.4257 - accuracy: 0.7689 - val_loss: 0.4900 - val_accuracy: 0.6800
# Epoch 40/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4156 - accuracy: 0.7733 - val_loss: 0.4736 - val_accuracy: 0.7200
# Epoch 41/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4308 - accuracy: 0.7511 - val_loss: 0.6190 - val_accuracy: 0.6800
# Epoch 42/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4612 - accuracy: 0.7422 - val_loss: 0.4306 - val_accuracy: 0.7200
# Epoch 43/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4424 - accuracy: 0.7867 - val_loss: 0.4590 - val_accuracy: 0.6800
# Epoch 44/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4319 - accuracy: 0.7644 - val_loss: 0.5644 - val_accuracy: 0.6400
# Epoch 45/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4249 - accuracy: 0.7911 - val_loss: 0.4704 - val_accuracy: 0.7200
# Epoch 46/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4300 - accuracy: 0.7956 - val_loss: 0.5236 - val_accuracy: 0.6800
# Epoch 47/100
# 12/12 [==============================] - 1s 48ms/step - loss: 0.4466 - accuracy: 0.7067 - val_loss: 0.4888 - val_accuracy: 0.6800
# Epoch 48/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4234 - accuracy: 0.7778 - val_loss: 0.4739 - val_accuracy: 0.6800
# Epoch 49/100
# 12/12 [==============================] - 1s 49ms/step - loss: 0.4344 - accuracy: 0.7600 - val_loss: 0.4450 - val_accuracy: 0.6400
# Epoch 50/100
# 12/12 [==============================] - 1s 44ms/step - loss: 0.4243 - accuracy: 0.7556 - val_loss: 0.4558 - val_accuracy: 0.6800
# Epoch 51/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4235 - accuracy: 0.7822 - val_loss: 0.5437 - val_accuracy: 0.6000
# Epoch 52/100
# 12/12 [==============================] - 1s 49ms/step - loss: 0.4262 - accuracy: 0.7644 - val_loss: 0.4402 - val_accuracy: 0.6800
# Epoch 53/100
# 12/12 [==============================] - 1s 48ms/step - loss: 0.4106 - accuracy: 0.7733 - val_loss: 0.4724 - val_accuracy: 0.6800
# Epoch 54/100
# 12/12 [==============================] - 0s 38ms/step - loss: 0.4380 - accuracy: 0.7556 - val_loss: 0.4512 - val_accuracy: 0.7600
# Epoch 55/100
# 12/12 [==============================] - 0s 40ms/step - loss: 0.4251 - accuracy: 0.7422 - val_loss: 0.5089 - val_accuracy: 0.7200
# Epoch 56/100
# 12/12 [==============================] - 0s 37ms/step - loss: 0.3991 - accuracy: 0.7778 - val_loss: 0.4903 - val_accuracy: 0.6400
# Epoch 57/100
# 12/12 [==============================] - 0s 37ms/step - loss: 0.4022 - accuracy: 0.7911 - val_loss: 0.4897 - val_accuracy: 0.6000
# Epoch 58/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4262 - accuracy: 0.7689 - val_loss: 0.4536 - val_accuracy: 0.7600
# Epoch 59/100
# 12/12 [==============================] - 0s 40ms/step - loss: 0.4216 - accuracy: 0.7733 - val_loss: 0.6534 - val_accuracy: 0.6800
# Epoch 60/100
# 12/12 [==============================] - 1s 48ms/step - loss: 0.4203 - accuracy: 0.7956 - val_loss: 0.4242 - val_accuracy: 0.7600
# Epoch 61/100
# 12/12 [==============================] - 1s 48ms/step - loss: 0.4075 - accuracy: 0.7778 - val_loss: 0.5115 - val_accuracy: 0.6400
# Epoch 62/100
# 12/12 [==============================] - 1s 62ms/step - loss: 0.3944 - accuracy: 0.7867 - val_loss: 0.4704 - val_accuracy: 0.6800
# Epoch 63/100
# 12/12 [==============================] - 1s 66ms/step - loss: 0.3956 - accuracy: 0.7822 - val_loss: 0.7916 - val_accuracy: 0.7200
# Epoch 64/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4005 - accuracy: 0.7867 - val_loss: 0.4939 - val_accuracy: 0.7600
# Epoch 65/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4085 - accuracy: 0.7911 - val_loss: 0.5196 - val_accuracy: 0.6800
# Epoch 66/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4193 - accuracy: 0.7556 - val_loss: 0.5001 - val_accuracy: 0.7200
# Epoch 67/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4423 - accuracy: 0.7956 - val_loss: 0.4709 - val_accuracy: 0.7200
# Epoch 68/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4509 - accuracy: 0.7689 - val_loss: 0.4752 - val_accuracy: 0.6800
# Epoch 69/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4085 - accuracy: 0.7911 - val_loss: 0.4746 - val_accuracy: 0.6400
# Epoch 70/100
# 12/12 [==============================] - 1s 49ms/step - loss: 0.4129 - accuracy: 0.8044 - val_loss: 0.5743 - val_accuracy: 0.6400
# Epoch 71/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4377 - accuracy: 0.7333 - val_loss: 0.5149 - val_accuracy: 0.6400
# Epoch 72/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4167 - accuracy: 0.7689 - val_loss: 0.6197 - val_accuracy: 0.6400
# Epoch 73/100
# 12/12 [==============================] - 0s 37ms/step - loss: 0.3966 - accuracy: 0.7778 - val_loss: 0.5281 - val_accuracy: 0.6800
# Epoch 74/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4030 - accuracy: 0.7911 - val_loss: 0.7190 - val_accuracy: 0.6000
# Epoch 75/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4238 - accuracy: 0.7600 - val_loss: 0.5636 - val_accuracy: 0.6400
# Epoch 76/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.4271 - accuracy: 0.7956 - val_loss: 0.5571 - val_accuracy: 0.6800
# Epoch 77/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4201 - accuracy: 0.7867 - val_loss: 0.6084 - val_accuracy: 0.6800
# Epoch 78/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.3915 - accuracy: 0.8133 - val_loss: 0.9171 - val_accuracy: 0.6800
# Epoch 79/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.3883 - accuracy: 0.8044 - val_loss: 0.5565 - val_accuracy: 0.6800
# Epoch 80/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.3754 - accuracy: 0.8044 - val_loss: 0.9017 - val_accuracy: 0.6400
# Epoch 81/100
# 12/12 [==============================] - 1s 43ms/step - loss: 0.4358 - accuracy: 0.8044 - val_loss: 0.5361 - val_accuracy: 0.7200
# Epoch 82/100
# 12/12 [==============================] - 1s 44ms/step - loss: 0.4708 - accuracy: 0.7422 - val_loss: 0.5239 - val_accuracy: 0.6800
# Epoch 83/100
# 12/12 [==============================] - 1s 68ms/step - loss: 0.4498 - accuracy: 0.7600 - val_loss: 0.4658 - val_accuracy: 0.6400
# Epoch 84/100
# 12/12 [==============================] - 1s 65ms/step - loss: 0.4039 - accuracy: 0.7778 - val_loss: 0.4914 - val_accuracy: 0.6400
# Epoch 85/100
# 12/12 [==============================] - 1s 72ms/step - loss: 0.3861 - accuracy: 0.7822 - val_loss: 0.5318 - val_accuracy: 0.6000
# Epoch 86/100
# 12/12 [==============================] - 1s 66ms/step - loss: 0.3705 - accuracy: 0.8133 - val_loss: 0.5075 - val_accuracy: 0.6800
# Epoch 87/100
# 12/12 [==============================] - 1s 47ms/step - loss: 0.3787 - accuracy: 0.8000 - val_loss: 0.5527 - val_accuracy: 0.7200
# Epoch 88/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.3577 - accuracy: 0.8222 - val_loss: 0.5592 - val_accuracy: 0.6800
# Epoch 89/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4003 - accuracy: 0.7511 - val_loss: 0.5428 - val_accuracy: 0.6400
# Epoch 90/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4369 - accuracy: 0.7244 - val_loss: 0.5965 - val_accuracy: 0.7200
# Epoch 91/100
# 12/12 [==============================] - 1s 43ms/step - loss: 0.4644 - accuracy: 0.7600 - val_loss: 0.4826 - val_accuracy: 0.6800
# Epoch 92/100
# 12/12 [==============================] - 1s 48ms/step - loss: 0.4174 - accuracy: 0.8089 - val_loss: 0.4793 - val_accuracy: 0.6400
# Epoch 93/100
# 12/12 [==============================] - 1s 49ms/step - loss: 0.4330 - accuracy: 0.7822 - val_loss: 0.5002 - val_accuracy: 0.6800
# Epoch 94/100
# 12/12 [==============================] - 1s 50ms/step - loss: 0.3878 - accuracy: 0.7689 - val_loss: 0.5635 - val_accuracy: 0.6400
# Epoch 95/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.3765 - accuracy: 0.7822 - val_loss: 0.4697 - val_accuracy: 0.6400
# Epoch 96/100
# 12/12 [==============================] - 1s 49ms/step - loss: 0.3601 - accuracy: 0.8044 - val_loss: 0.5342 - val_accuracy: 0.7600
# Epoch 97/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.3815 - accuracy: 0.8044 - val_loss: 0.5137 - val_accuracy: 0.6800
# Epoch 98/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.3495 - accuracy: 0.8000 - val_loss: 0.4748 - val_accuracy: 0.6400
# Epoch 99/100
# 12/12 [==============================] - 1s 45ms/step - loss: 0.3476 - accuracy: 0.7956 - val_loss: 0.5157 - val_accuracy: 0.6800
# Epoch 100/100
# 12/12 [==============================] - 1s 46ms/step - loss: 0.3499 - accuracy: 0.8222 - val_loss: 0.5734 - val_accuracy: 0.6000
# 62/62 [==============================] - 1s 9ms/step

# %% [markdown]
# On observe du **sur-apprentissage** ! L'accuracy d'entrainement est élevée, mais l'accuracy de validation est faible. On doit alors chercher à limiter le sur-apprentissage, et pour ce faire on peut utiliser des techniques de régularisation. Une des techniques vues en cours consiste à appliquer une pénalité sur la norme des paramètres du modèle. Ainsi, plutôt que de minimiser une fonction objectif $J(\theta)$ classique :
# $$ J(\theta) = \frac{1}{n} \sum_{i=1}^{n} \text{loss}(y^{(i)}, \hat{y}^{(i)}) $$
#
# on minimise plutôt :
# $$ J(\theta) = \frac{1}{n} \sum_{i=1}^{n} \text{loss}(y^{(i)}, \hat{y}^{(i)}) + \lambda \sum_{j=1}^M \theta_j^2 $$
#
# où $M$ désigne le nombre de paramètres (poids synaptiques et biais) du réseau, $\theta$ désigne les paramètres du réseau.
#
# En pratique il suffit d'appliquer cette pénalisation aux poids synaptiques seuls (car ils sont beaucoup plus nombreux).
#
# La librairie Keras permet d'appliquer de la régularisation à n'importe quelle couche, [comme décrit sur cette page.](https://keras.io/api/layers/regularizers/)
#
# **Travail à faire**: Reprenez votre réseau précédent (avec lequel on obtenait du sur-apprentissage) et intégrez de la régularisation pour limiter le sur-apprentissage.

# %% [markdown]
# ## Problème à 3 classes
#
# Tous les problèmes que nous avons abordés jusqu'à maintenant étaient des problèmes de classification binaire (fonction d'activation sigmoide).
#
# Dans cette section nous définissons un jeu de données comportant trois classes.

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# Génération des données
x, y = datasets.make_blobs(n_samples=500, n_features=2, centers=3, center_box=(- 5, 5), random_state=3)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')
plt.plot(x_train[y_train==2,0], x_train[y_train==2,1], 'g.', label='Apprentissage, classe 2')

plt.xlabel('x1')
plt.ylabel('x2')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')
plt.plot(x_test[y_test==2,0], x_test[y_test==2,1], 'g+', label='Test, classe 1')

plt.legend()
plt.show()

# %% [markdown]
# La fonction ci-dessous permet d'afficher les frontières de décision apprises par le modèle.

# %%
def print_decision_boundaries_3classes(model, x, y):
    # Adjust step sizes to match the input data
    dx = (np.max(x[:, 0]) - np.min(x[:, 0])) / 100
    dy = (np.max(x[:, 1]) - np.min(x[:, 1])) / 100

    # Create a grid with adjusted step sizes
    y_grid, x_grid = np.mgrid[slice(np.min(x[:, 1]), np.max(x[:, 1]) + dy, dy),
                               slice(np.min(x[:, 0]), np.max(x[:, 0]) + dx, dx)]

    # Generate points for prediction
    x_gen = np.stack((x_grid.ravel(), y_grid.ravel()), axis=-1)
    y_pred_gen = np.argmax(model.predict(x_gen), axis=1)
    z_gen = y_pred_gen.reshape(x_grid.shape)

    # Define color range
    z_min, z_max = 0, 2

    # Plot decision boundaries
    c = plt.pcolor(x_grid, y_grid, z_gen, cmap='brg', vmin=z_min, vmax=z_max, alpha=0.5)
    plt.colorbar(c)

    # Plot data points for each class
    plt.plot(x[y == 0, 0], x[y == 0, 1], 'bo', label='Class 0')
    plt.plot(x[y == 1, 0], x[y == 1, 1], 'ro', label='Class 1')
    plt.plot(x[y == 2, 0], x[y == 2, 1], 'go', label='Class 2')

    # Add legend
    plt.legend()
    plt.show()

# %% [markdown]
# Lorsque les données appartiennent à plus de deux classes, il est nécessaire de formater les labels sous la forme de *one-hot vectors*, c'est-à-dire de de vecteurs constitués de 0 et d'un 1 à l'indice de la classe correspondante.
#
# Ainsi, pour un problème à 3 classes :
# - si $x^{(i)}$ appartient à la classe 0, $y^{(i)} = [1, 0, 0]^T$
# - si $x^{(i)}$ appartient à la classe 1, $y^{(i)} = [0, 1, 0]^T$
# - si $x^{(i)}$ appartient à la classe 2, $y^{(i)} = [0, 0, 1]^T$
#
# Dans le jeu de données introduit plus haut, les labels $y \in \{0, 1, 2\}$. Pour les convertir au format *one-hot*, vous pouvez utiliser la fonction [to_categorical](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical).
#
# **Travail à faire**: Construisez un perceptron monocouche capable de résoudre ce problème de classification à 3 classes.

# %%
model = Sequential()
model.add(Dense(3, activation='softmax', input_dim=2))

adam = optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)
plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-e8fe2cf87be5> in <cell line: 9>()
#       7               metrics=['accuracy'])
#       8
# ----> 9 history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)
#      10 plot_training_analysis(history)
#      11 print_decision_boundaries(model, x_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1151, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1209, in compute_loss
#         return self.compiled_loss(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 277, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 143, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 270, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 2221, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 5573, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 3) are incompatible

# %% [markdown]
# # Application à une base de données réelle
#
# Pour mettre en application les notions vues précédemment, téléchargez les données suivantes.

# %%
# !wget acarlier.fr/tp/HA_dataset.csv

# %%
import csv
from sklearn.model_selection import train_test_split

x = []
y = []

# Lecture du fichier CSV et des données
with open('HA_dataset.csv', 'r') as file:
    reader = csv.reader(file)
    headers = next(reader)  # Ligne d'en-tête
    for row in reader:
        x.append([float(value) for value in row[:-1]])  # Toutes les colonnes à l'exception de la dernières sont les variables d'entrée
        y.append(int(row[-1]))  # La dernière colonne constitue le label à prédire

x = np.array(x)
y = np.array(y)

# Séparation des données en jeux d'apprentissage et de test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Affichage de la dimension des données
print("Dimension de x_train:", x_train.shape)
print("Dimension de y_train:", y_train.shape)
print("Dimension de x_test:", x_test.shape)
print("Dimension de y_test:", y_test.shape)

# %% [markdown]
# Ces données sont issues de https://archive.ics.uci.edu/dataset/45/heart+disease et regroupent des caractéristiques de patients risquant ($y=1$) de développer une attaque cardiaque. Voici les différentes caractéristiques sur lesquelles votre modèle pourra s'appuyer pour établir un pronostic :
# - *age* : Âge du patient
# - *sex* : Sexe du patient (0-1)
# - *exang* : Angine induite par l'exercice (1 = oui ; 0 = non)
# - *ca* : Nombre de vaisseaux principaux (0-3)
# - *cp* : Type de douleur thoracique (1-4)
# - *trestbps* : Pression artérielle au repos (en mm de mercure)
# - *chol* : Cholestérol en mg/dl récupéré via un capteur BMI
# - *fbs* : (glycémie à jeun > 120 mg/dl) (1 = vrai ; 0 = faux)
# - *restecg* : Résultats électrocardiographiques au repos (0-2)
# - *thalach* : Fréquence cardiaque maximale atteinte
# - *oldpeak* : Dépression du segment ST induite par l'exercice par rapport au repos
# - *slope*, *thal* : signification non renseignée

# %% [markdown]
# **Travail à faire** : Construisez un classifieur permettant d'obtenir les meilleurs résultats possibles sur l'ensemble de test de ce jeu de données.
#
#
# **N.B.** Prenez garde à l'échelle des données d'entrée ! Le code ci-dessous vous permettra de les répresenter sous forme graphique. Il peut être intéressant de les normaliser...

# %%
import matplotlib.pyplot as plt


combined_data = np.column_stack((x_train, y_train))
combined_data_transposed = list(map(list, zip(*combined_data)))

# Création d'un "diagramme à moustache"
plt.figure(figsize=(10, 6))
plt.boxplot(combined_data_transposed, labels=headers[:-1] + ['target'])
plt.xticks(rotation=45)
plt.title('Distribution des valeurs de chacune des variables')
plt.xlabel('Variables')
plt.ylabel('Valeurs')
plt.yscale('log')  # Echelle logarithmique

plt.grid(True)
plt.tight_layout()
plt.show()
